# %%
import IPython.display
from IPython.display import Image
import folium

# %% [markdown]
# Zuerst suchen wir die Satellitenbilddaten mit dem Browser von Copernicus Data Space Ecosystem.

# %%
Image("C:\\Users\\Dell\\Desktop\\Geospatial Analysis Projekte\\Geodaten\\Sentinel 2 -Bilder\\Copernicus Data Space Ecosystem - Browser.jpg", width=1000, height=500)

# %% [markdown]
# Wir bekommen ein Beispielbild.

# %%
Image("C:\\Users\\Dell\\Desktop\\Geospatial Analysis Projekte\\Geodaten\\Sentinel 2 -Bilder\\Ackerland.jpg", width=1000, height=500)

# %% [markdown]
# Mit QGIS können wir verschiedene Polygone zeichnen für verschiedene Kulturpflanzenarten.

# %%
Image("C:\\Users\\Dell\\Desktop\\Geospatial Analysis Projekte\\Geodaten\\Sentinel 2 -Bilder\\QGIS - Ackerland.jpg", width=1000, height=500)

# %% [markdown]
# Es ist möglich ein tiefes neuronales Netzwerk zu verwenden, z.B. die U-Net Architektur hat einen Algorithmus für die richtige Bildverarbeitung.

# %%
Image("C:\\Users\\Dell\\Desktop\\Geospatial Analysis Projekte\\Geodaten\\Sentinel 2 -Bilder\\Ackerland für Feldfrüchte.jpg", width=1000, height=500)

# %% [markdown]
# Wir können auch interaktive Karten mit folium für unsere Analyse machen.

# %%
Ackerland = [50.936085, 10.910645]
Ackerland = folium.Map(Ackerland, zoom_start = 15, tiles = 'openstreetmap')
Ackerland
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
